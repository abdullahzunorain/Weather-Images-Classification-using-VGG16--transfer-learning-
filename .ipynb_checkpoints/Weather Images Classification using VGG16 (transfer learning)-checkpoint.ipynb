# %% [markdown]
#                                             Abdullah Zunorain

# %% [markdown]
# ## Instructions:
#
#         Download the dataset using this link.
#
#        Split the data into test and train folders.
#
#        Organize your dataset into a clear directory structure.
#
#        Apply techniques to expand the dataset(Data augmentation).
#
#        Create a data pipeline for loading and preprocessing images.
#
#        Use a pre-trained model and fine-tune it for your classification task.
#
#        Train the model for the specified number of epochs and validate its performance.Keep the epochs 2

# %%
# dataset directory
path_data_Org = r'C:\Users\lenovo\OneDrive\Desktop\AI Bootcamp (atomcamp)\Computer Vision\S6 Class_activity\dataset'

path_data_copy = r'C:\Users\lenovo\OneDrive\Desktop\AI Bootcamp (atomcamp)\Computer Vision\S6 Class_activity\dataset - Copy'

weather_dataset = r'C:\Users\lenovo\OneDrive\Desktop\AI Bootcamp (atomcamp)\Computer Vision\S6 Class_activity\weather_data'

# %%
# weather_dataset

# %% [markdown]
#     - the below code snippet will splits the images into `test` and `train` folder in a `weather_data` folder.

# %%
# import os
# import shutil
# from sklearn.model_selection import train_test_split

# # Define paths
# original_dataset_dir = path_data_copy
# base_dir = r'C:\Users\lenovo\OneDrive\Desktop\AI Bootcamp (atomcamp)\Computer Vision\S6 Class_activity\weather_data'


# train_dir = os.path.join(base_dir, 'train')
# os.makedirs(train_dir, exist_ok=True)

# test_dir = os.path.join(base_dir, 'test')
# os.makedirs(test_dir, exist_ok=True)

# # Weather conditions
# weather_conditions = ['cloudy', 'foggy', 'rainy', 'shine', 'sunrise']

# # Create train and test directories for each class
# for condition in weather_conditions:
#     os.makedirs(os.path.join(train_dir, condition), exist_ok=True)
#     os.makedirs(os.path.join(test_dir, condition), exist_ok=True)

# # Function to split data into train and test sets
# def split_data(source_dir, train_dir, test_dir, split_size=0.8):
#     files = os.listdir(source_dir)
#     train_files, test_files = train_test_split(files, test_size=(1 - split_size), random_state=42)
    
#     for file in train_files:
#         src = os.path.join(source_dir, file)
#         dst = os.path.join(train_dir, file)
#         shutil.copyfile(src, dst)
        
#     for file in test_files:
#         src = os.path.join(source_dir, file)
#         dst = os.path.join(test_dir, file)
#         shutil.copyfile(src, dst)

# # Split data for each weather condition
# for condition in weather_conditions:
#     source_dir = os.path.join(original_dataset_dir, condition)
#     train_condition_dir = os.path.join(train_dir, condition)
#     test_condition_dir = os.path.join(test_dir, condition)
#     split_data(source_dir, train_condition_dir, test_condition_dir)

# print("Data split into train and test directories successfully.")

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import cv2
# Technically not necessary in newest versions of jupyter
# %matplotlib inline

# %%
weat_1 = cv2.imread(r'C:\Users\lenovo\OneDrive\Desktop\AI Bootcamp (atomcamp)\Computer Vision\S6 Class_activity\weather_data\test\foggy\foggy42.jpg')

plt.imshow(weat_1)

# %%
# orignal rgb image..
weat_1 = cv2.cvtColor(weat_1, cv2.COLOR_BGR2RGB) # convert bgr image into rgb
plt.imshow(weat_1);

# %%
image_gen = ImageDataGenerator(
    rotation_range=30, # rotate the image 30 degrees
    width_shift_range=0.1, # Shift the pic width by a max of 10%                           
    height_shift_range=0.1, # Shift the pic height by a max of 10%
    rescale=1/255, # Rescale the image by normalzing it.
    shear_range=0.2, # Shear means cutting away part of the image (max 20%)
    zoom_range=0.2, # Zoom in by 20% max
    horizontal_flip=True, # Allo horizontal flipping
    fill_mode='nearest' # Fill in missing pixels with the nearest filled value                   
)

# %%
weat_1.shape
# Out:
# (600, 800, 3)

# %%
# type(image_gen)

# %%
# dir(image_gen)

# %%
# 
plt.imshow(image_gen.random_transform(weat_1))

# %%
plt.imshow(image_gen.random_transform(weat_1));

# %%
image_gen.flow_from_directory('./weather_data/train/');
# Out:
# Found 1200 images belonging to 5 classes.

# %%
image_gen.flow_from_directory('./weather_data/test/');
# Out:
# Found 300 images belonging to 5 classes.

# %% [markdown]
# ***

# %% [markdown]
# #### Resizing Images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Define directories for train and test data
train_dir = './weather_data/train/'
test_dir = './weather_data/test/'

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 16

# Create data generators for train and test data
train_datagen = ImageDataGenerator(
    rotation_range=30,  # rotate the image 30 degrees
    width_shift_range=0.1,  # Shift the pic width by a max of 10%                           
    height_shift_range=0.1,  # Shift the pic height by a max of 10%
    rescale=1/255,  # Rescale the image by normalizing it.
    shear_range=0.2,  # Shear means cutting away part of the image (max 20%)
    zoom_range=0.2,  # Zoom in by 20% max
    horizontal_flip=True,  # Allow horizontal flipping
    fill_mode='nearest'  # Fill in missing pixels with the nearest filled value
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'  # Updated to 'categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'  # Updated to 'categorical'
)

# Debugging: Print a batch of data to ensure it's correctly loaded
x_batch, y_batch = next(train_generator)
print(f"x_batch shape: {x_batch.shape}, y_batch shape: {y_batch.shape}")

# Load pre-trained VGG16 model without top layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new sequential model
model = Sequential()

# Add the VGG16 base model
model.add(base_model)

# Flatten the output of the VGG16 base model
model.add(Flatten())

# Add custom top layers for classification
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))  # Updated to 5 units with softmax activation

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',  # Updated to categorical_crossentropy
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,  # Adjust steps_per_epoch
    epochs=2,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size  # Adjust validation_steps
)

# Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Found 1200 images belonging to 5 classes.
# Found 300 images belonging to 5 classes.
# x_batch shape: (16, 224, 224, 3), y_batch shape: (16, 5)
# Epoch 1/2
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 275s 4s/step - accuracy: 0.4173 - loss: 1.4236 - val_accuracy: 0.8021 - val_loss: 0.6849
# Epoch 2/2
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6667 - val_loss: 0.8255

# %% [markdown]
# ***

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
train_path = 'weather_data/train/'
valid_path = 'weather_data/Test'

# %%
# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# don't train existing weights
for layer in vgg.layers:
    layer.trainable = False

# %%
# useful for getting number of classes
folders = glob('weather_data/train/*')
folders
# Out:
# ['weather_data/train\\cloudy',
#  'weather_data/train\\foggy',
#  'weather_data/train\\rainy',
#  'weather_data/train\\shine',
#  'weather_data/train\\sunrise']

# %%
# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('weather_data/train/',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical'
                                                )


test_set = test_datagen.flow_from_directory('weather_data/test/',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical'
                                           )
# Out:
# Found 1200 images belonging to 5 classes.
# Found 300 images belonging to 5 classes.

# %%
# Calculate the steps per epoch
steps_per_epoch = training_set.samples // training_set.batch_size
validation_steps = test_set.samples // test_set.batch_size

# %%
# Train the model
r = model.fit(
    training_set,
    validation_data=test_set,
    epochs=2,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)
# Out:
# Epoch 1/2
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 248s 7s/step - accuracy: 0.5180 - loss: 1.2311 - val_accuracy: 0.8507 - val_loss: 0.3972
# Epoch 2/2
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.7500 - loss: 0.5151 - val_accuracy: 0.6667 - val_loss: 0.5185

# %%
# Plot the training history
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ***
# ***

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from glob import glob

# Define image size and paths
IMAGE_SIZE = [224, 224]
train_path = 'weather_data/train/'
valid_path = 'weather_data/test/'

# Load VGG16 model + higher level layers
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# Freeze the pre-trained model's layers
for layer in vgg.layers:
    layer.trainable = False

# Get the number of classes
folders = glob('weather_data/train/*')

# Create our model
model = Sequential([
    vgg,
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(len(folders), activation='softmax')
])

# Build the model with the input shape
model.build(input_shape=(None, 224, 224, 3))

# View the structure of the model
model.summary()

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# Image data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_set = test_datagen.flow_from_directory(
    valid_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Calculate the steps per epoch
steps_per_epoch = training_set.samples // training_set.batch_size
validation_steps = test_set.samples // test_set.batch_size

# Train the model
r = model.fit(
    training_set,
    validation_data=test_set,
    epochs=5,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)

# Plot the training history
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1024)                │      25,691,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1024)                │               0 │
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from glob import glob
from sklearn.metrics import classification_report, confusion_matrix

# Define image size and paths
IMAGE_SIZE = [224, 224]
train_path = 'weather_data/train/'
valid_path = 'weather_data/test/'

# Load VGG16 model + higher level layers
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# Freeze the pre-trained model's layers
for layer in vgg.layers:
    layer.trainable = False

# Get the number of classes
folders = glob('weather_data/train/*')

# Create our model
model = Sequential([
    vgg,
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(len(folders), activation='softmax')
])

# Build the model with the input shape
model.build(input_shape=(None, 224, 224, 3))

# View the structure of the model
model.summary()

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# Image data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_set = test_datagen.flow_from_directory(
    valid_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # Important for making predictions in the correct order
)

# Calculate the steps per epoch
steps_per_epoch = training_set.samples // training_set.batch_size
validation_steps = test_set.samples // test_set.batch_size

# Train the model
r = model.fit(
    training_set,
    validation_data=test_set,
    epochs=2,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)

# Predict the classes for the test set
predictions = model.predict(test_set, steps=len(test_set), verbose=1)
predicted_classes = np.argmax(predictions, axis=1)

# True labels
true_classes = test_set.classes
class_labels = list(test_set.class_indices.keys())

# Generate the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1024)                │      25,691,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 1024)                │               0 │
# ...

# %%
# import tensorflow as tf
# from keras.models import load_model

# model.save('weather_classification_model.h5')
